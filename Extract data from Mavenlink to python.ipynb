# %%
import pandas as pd
import numpy as np
data = pd.read_excel("/Users/annette/Downloads/all_tasks_feb_10.xlsx")

# %%
data
# Out:
#              Id                                            Project  \
# 0     144881677  Robin Hood Foundation - SOW-8 - Fundraising En...
# 1     144881687  Robin Hood Foundation - SOW-8 - Fundraising En...
# 2     144881707  Robin Hood Foundation - SOW-8 - Fundraising En...
# 3     144882207  Robin Hood Foundation - SOW-8 - Fundraising En...
# 4     144883157  Robin Hood Foundation - SOW-8 - Fundraising En...
# ...         ...                                                ...
# 9535  516287515  Higher Achievement - SOW-4 - 12-months of Support
# 9536  516540845  Yurgosky {Quota} - Classes - Version 1.0 and A...
# 9537  516542665  Yurgosky {Quota} - Classes - Version 1.0 and A...
# 9538  516545825  Whittle School - SOW-1 - Creating a Foundation...
# 9539  516547815  Higher Achievement - SOW-4 - 12-months of Support
#
#                                                Groups  \
# 0     Client, General Contract, Robin Hood Foundation
# ...

# %%
pip install sqlalchemy pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
